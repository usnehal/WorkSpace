# %%
#!/usr/bin/env python3

# %%
import socket
import os
import json
import  time
import tensorflow as tf
import numpy as np
from   nltk.translate.bleu_score import sentence_bleu
import random
import  re
import sys
import argparse

from   Config import Config
import Util
import Logger
from   Communication import Client
from ImagesInfo import ImagesInfo
from TimeKeeper import TimeKeeper

# %%
parser = argparse.ArgumentParser()
parser.add_argument('-s', '--server', action='store', type=str, required=False)
parser.add_argument('-t', '--test_number', action='store', type=int, required=False)
parser.add_argument('-v', '--verbose', action='store', type=int, required=False)
args, unknown = parser.parse_known_args()
print(args.server)

server_ip = args.server
test_number = args.test_number
verbose = args.verbose

if(verbose == None):
    verbose = 1

if(test_number == None):
    test_number = 2

test_scenarios = {1:"Complete jpg file buffer transfer", 2:"Decoded image buffer transfer"}

print("Test scenario = %d %s" % (test_number, test_scenarios[test_number]))
# Out:
# None
# Test scenario = 2 Decoded image buffer transfer

# %%
Logger.set_log_level(verbose)
tk = TimeKeeper()
cfg = Config(server_ip)
client = Client(cfg)
imagesInfo = ImagesInfo(cfg)
# Out:
# In WSL

# %%
#!/usr/bin/env python3
import os
import numpy as np
import tensorflow as tf
from   tensorflow.keras import layers,Model
import pickle5 as pickle
from   tensorflow.keras.preprocessing.text import Tokenizer
from   tensorflow.keras.activations import tanh
from   tensorflow.keras.activations import softmax
from   numpy import float32
import json
import time

from Config import Config
import Logger
from Communication import Server
import Util
class Encoder(Model):
    def __init__(self,embed_dim):
        super(Encoder, self).__init__()
        # build your Dense layer with relu activation
        self.dense = tf.keras.layers.Dense(embed_dim, activation='relu')
        
    def call(self, features):
        # extract the features from the image shape: (batch, 8*8, embed_dim)
        features = self.dense(features)
        return features    

class Attention_model(Model):
    def __init__(self, units):
        super(Attention_model, self).__init__()
        self.units=units
        # build your Dense layer
        self.W1 = tf.keras.layers.Dense(units)
        # build your Dense layer
        self.W2 = tf.keras.layers.Dense(units)
        # build your final Dense layer with unit 1
        # self.V = tf.keras.layers.Dense(1, activation='softmax')
        self.V = tf.keras.layers.Dense(1)

    def call(self, features, hidden):
        # features shape: (batch_size, 8*8, embedding_dim)
        # hidden shape: (batch_size, hidden_size)
        
        # Expand the hidden shape to shape: (batch_size, 1, hidden_size)
        hidden_with_time_axis = tf.expand_dims(hidden, 1)
        # build your score funciton to shape: (batch_size, 8*8, units)
        score = tanh(self.W1(features) + self.W2(hidden_with_time_axis))
        # extract your attention weights with shape: (batch_size, 8*8, 1)
        score = self.V(score)
        attention_weights = softmax(score, axis=1)

        # shape: create the context vector with shape (batch_size, 8*8,embedding_dim)
        context_vector = attention_weights * features
        # reduce the shape to (batch_size, embedding_dim)
        # context_vector = tf.reduce_sum(context_vector, axis=1)
        context_vector = tf.reduce_mean(context_vector, axis=1)

        return context_vector, attention_weights   
class Decoder(Model):
    def __init__(self, embed_dim, units, vocab_size, cfg):
        super(Decoder, self).__init__()
        self.cfg = cfg
        self.units = units
        # iniitalise your Attention model with units
        self.attention = Attention_model(self.units)
        # build your Embedding layer
        self.embed = tf.keras.layers.Embedding(vocab_size, self.cfg.embedding_dim)
        self.gru = tf.keras.layers.GRU(self.units,return_sequences=True,return_state=True,recurrent_initializer='glorot_uniform')
        # build your Dense layer
        self.d1 = tf.keras.layers.Dense(self.units)
        # build your Dense layer
        self.d2 = tf.keras.layers.Dense(vocab_size)


    def call(self,x,features, hidden):
        #create your context vector & attention weights from attention model
        context_vector, attention_weights = self.attention(features, hidden)
        # embed your input to shape: (batch_size, 1, embedding_dim)
        embed = self.embed(x)
        # Concatenate your input with the context vector from attention layer. 
        # Shape: (batch_size, 1, embedding_dim + embedding_dim)
        embed = tf.concat([tf.expand_dims(context_vector, 1), embed], axis=-1)
        # Extract the output & hidden state from GRU layer. 
        # Output shape : (batch_size, max_length, hidden_size)
        output, state = self.gru(embed)
        output = self.d1(output)
        # shape : (batch_size * max_length, hidden_size)
        output = tf.reshape(output, (-1, output.shape[2])) 
        # shape : (batch_size * max_length, vocab_size)
        output = self.d2(output)

        return output, state, attention_weights

    def init_state(self, batch_size):
        return tf.zeros((batch_size, self.units))
class TailModel:
    def __init__(self,cfg):
        self.cfg = cfg

        with open(self.cfg.saved_model_path + '/tokenizer.pickle', 'rb') as handle:
            self.tokenizer = pickle.load(handle)
        
        with open(self.cfg.saved_model_path + '/image_features_extract_model.json', 'r') as json_file:
            json_savedModel= json_file.read()
        self.image_features_extract_model = tf.keras.models.model_from_json(json_savedModel)
        self.image_features_extract_model.load_weights(self.cfg.saved_model_path + '/image_features_extract_model.h5')
        vocab_size = cfg.max_tokenized_words + 1

        s = tf.zeros([32, 64, 2048], tf.int32)

        self.encoder=Encoder(self.cfg.embedding_dim)

        self.decoder=Decoder(self.cfg.embedding_dim, self.cfg.units, vocab_size,cfg)

        features = self.encoder(s)

        hidden = self.decoder.init_state(batch_size=self.cfg.batch_size)
        dec_input = tf.expand_dims([self.tokenizer.word_index['<start>']] * self.cfg.batch_size, 1)

        predictions, hidden_out, attention_weights= self.decoder(dec_input, features, hidden)

        self.decoder.load_weights(self.cfg.saved_model_path + "/decoder.h5")
        self.encoder.load_weights(self.cfg.saved_model_path + "/encoder.h5")

    def evaluate(self,image):
        attention_features_shape = 64
        attention_plot = np.zeros((self.cfg.MAX_SEQ_LENGTH, attention_features_shape))

        hidden = self.decoder.init_state(batch_size=1)

        # process the input image to desired format before extracting features
        temp_input = tf.expand_dims(image, 0) 
        # Extract features using our feature extraction model
        img_tensor_val = self.extract_image_features(temp_input)
        # img_tensor_val = tf.reshape(img_tensor_val, (img_tensor_val.shape[0], -1, img_tensor_val.shape[3]))

        # extract the features by passing the input to encoder
        features = self.encoder(img_tensor_val)

        dec_input = tf.expand_dims([self.tokenizer.word_index['<start>']], 0)
        result = []

        for i in range(self.cfg.MAX_SEQ_LENGTH):
            # get the output from decoder
            predictions, hidden, attention_weights = self.decoder(dec_input, features, hidden)

            attention_plot[i] = tf.reshape(attention_weights, (-1, )).numpy()

            #extract the predicted id(embedded value) which carries the max value
            predicted_id = tf.argmax(tf.transpose(predictions))
            predicted_id = predicted_id.numpy()[0]
            # map the id to the word from tokenizer and append the value to the result list
            result.append(self.tokenizer.index_word[predicted_id])

            if self.tokenizer.index_word[predicted_id] == '<end>':
                return result, attention_plot,predictions

            dec_input = tf.expand_dims([predicted_id], 0)

        attention_plot = attention_plot[:len(result), :]
        return result, attention_plot,predictions

    def process_image_file(self,msg,shape):
        temp_file = '/tmp/temp.bin'
        f = open(temp_file, "wb")
        f.write(msg)
        f.close()

        image_tensor,label = Util.read_image(temp_file,[])

        t0 = time.perf_counter()
        result, attention_plot,pred_test  = self.evaluate(image_tensor)
        t1 = time.perf_counter() - t0
        pred_caption=' '.join(result).rsplit(' ', 1)[0]

        send_json_dict = {}
        send_json_dict['response'] = 'OK'
        send_json_dict['pred_caption'] = pred_caption
        send_json_dict['tail_model_time'] = t1

        app_json = json.dumps(send_json_dict)

        return str(app_json)

    def process_image_tensor(self,msg,shape):
        generated_np_array = np.frombuffer(msg, dtype=float32)
        generated_image_np_array = generated_np_array.reshape(shape)
        image_tensor = tf.convert_to_tensor(generated_image_np_array, dtype=tf.float32)

        t0 = time.perf_counter()
        result, attention_plot,pred_test  = self.evaluate(image_tensor)
        t1 = time.perf_counter() - t0
        pred_caption=' '.join(result).rsplit(' ', 1)[0]

        send_json_dict = {}
        send_json_dict['response'] = 'OK'
        send_json_dict['pred_caption'] = pred_caption
        send_json_dict['tail_model_time'] = t1

        app_json = json.dumps(send_json_dict)

        return str(app_json)
        
    def extract_image_features(self, sample_img_batch):
        features = self.image_features_extract_model(sample_img_batch)
        features = tf.reshape(features, [sample_img_batch.shape[0],8*8, 2048])
        return features

# cfg = Config(None)
tailModel = TailModel(cfg)
# server = Server(cfg, tailModel)
# server.register_callback('data',tailModel.process_image_tensor)
# server.register_callback('file',tailModel.process_image_file)
# server.accept_connections()

# server.callbacks

# %%
if False:
    with open(file_name, 'rb') as file_t:
        blob_data = bytearray(file_t.read())
        send_json_dict = {}
        send_json_dict['data_type'] = 'file'
        send_json_dict['file_name'] = file_name
        send_json_dict['data_size'] = (len(blob_data))
        # send_json_dict['data_buffer'] = blob_data
        app_json = json.dumps(send_json_dict)
        print(str(app_json))

        t0= time.perf_counter()
        client.send_data(str(app_json), blob_data)
        t1 = time.perf_counter() - t0

        print("Time to send file: %.3f" % (t1))
def evaluate_file_over_server(file_name):
    with open(file_name, 'rb') as file_t:
        byte_buffer_to_send = bytearray(file_t.read())
        send_json_dict = {}
        send_json_dict['data_type'] = 'file'
        send_json_dict['file_name'] = file_name
        send_json_dict['data_size'] = (len(byte_buffer_to_send))
        send_json_dict['data_shape'] = "(%d,)" % (len(byte_buffer_to_send))
        # send_json_dict['data_buffer'] = blob_data

        app_json = json.dumps(send_json_dict)

        tk.logInfo(img_path, tk.I_BUFFER_SIZE, len(byte_buffer_to_send))

        tk.logTime(img_path, tk.E_START_COMMUNICATION)

        # response = client.send_data(str(app_json), byte_buffer_to_send)
        response = tailModel.process_image_file(byte_buffer_to_send, "(%d,)" % (len(byte_buffer_to_send)))

        tk.logTime(img_path, tk.E_STOP_COMMUNICATION)

        response = json.loads(response)

        pred_caption = response['pred_caption']
        tail_model_time = response['tail_model_time']
        tk.logInfo(img_path, tk.I_TAIL_MODEL_TIME, tail_model_time)

        return pred_caption, [], []

# %%
# tf.compat.v1.disable_eager_execution()

# %%
def evaluate_over_server(file_name):
    image_tensor,caption = Util.read_image(file_name,'')

    image_np_array = image_tensor.numpy()

    byte_buffer_to_send = image_np_array.tobytes()
    type(byte_buffer_to_send)

    send_json_dict = {}
    send_json_dict['data_type'] = 'data'
    send_json_dict['file_name'] = file_name
    send_json_dict['data_size'] = (len(byte_buffer_to_send))
    send_json_dict['data_shape'] = image_np_array.shape

    app_json = json.dumps(send_json_dict)

    tk.logInfo(img_path, tk.I_BUFFER_SIZE, len(byte_buffer_to_send))

    tk.logTime(img_path, tk.E_START_COMMUNICATION)

    # response = client.send_data(str(app_json), byte_buffer_to_send)
    response = tailModel.process_image_tensor(byte_buffer_to_send,image_np_array.shape)

    tk.logTime(img_path, tk.E_STOP_COMMUNICATION)

    response = json.loads(response)

    pred_caption = response['pred_caption']
    tail_model_time = response['tail_model_time']
    tk.logInfo(img_path, tk.I_TAIL_MODEL_TIME, tail_model_time)

    return pred_caption, [], []

# %%
total_time = 0.0
max_test_images = cfg.total_test_images
for i in range(max_test_images):
    Logger.event_print("")
    random_num = random.randint(0,max_test_images-1)
    img_path = imagesInfo.getImagePath(random_num)
    # image = io.imread(img_path)
    # plt.imshow(image)

    real_caption = imagesInfo.getCaption(random_num)

    tk.startRecord(img_path)
    tk.logTime(img_path, tk.E_START_CLIENT_PROCESSING)

    if(test_number == 1):
        pred_caption, attention_plot,pred_test = evaluate_file_over_server(img_path)
    if(test_number == 2):
        pred_caption, attention_plot,pred_test = evaluate_over_server(img_path)

    tk.logTime(img_path, tk.E_STOP_CLIENT_PROCESSING)

    real_caption=Util.filt_text(real_caption)      

    reference = imagesInfo.getAllCaptions(img_path)
    candidate = pred_caption.split()

    score = sentence_bleu(reference, candidate, weights=[1]) #set your weights)

    tk.logInfo(img_path, tk.I_BLEU, score)
    tk.logInfo(img_path, tk.I_REAL_CAPTION, real_caption)
    tk.logInfo(img_path, tk.I_PRED_CAPTION, pred_caption)
    tk.finishRecord(img_path)

    Logger.event_print("BLEU: %.2f" % (score))
    Logger.event_print ('Real: %s' % (real_caption))
    Logger.event_print ('Pred: %s' % (pred_caption))

tk.printAll()
tk.summary()
# Out:
# BLEU: 0.50
# Real: two women walking through a parking lot carrying luggage
# Pred: a woman is walking down the street
#
# BLEU: 0.82
# Real: a large tractor truck with a painting on the back of the cab
# Pred: a truck with a skateboard on the back of a truck
#
# BLEU: 0.35
# Real: an nypd police car sitting on broadway near a stoplight
# Pred: a busy city street with a street with a street light on a street
#
# BLEU: 0.60
# Real: a baby puts a tooth brush in its mouth
# Pred: a young child brushing her teeth
#
# BLEU: 0.25
# Real: wires traffic and street signs at the corner of 51st and 72nd
# Pred: a street sign on a pole on a pole on a pole on a pole on a pole on a pole on a pole
#
# BLEU: 0.75
# Real: a large jetliner parked on an airport tarmac
# Pred: a large white airplane parked on the tarmac
#
# BLEU: 0.70
# Real: person holding a cut red grapefruit showing a large seed
# Pred: a close up of an orange on a wooden table
#
# BLEU: 0.70
# Real: the fresh orange has been cut and is ready to be eaten
# Pred: a close up of an orange on a wooden table
#
# BLEU: 0.35
# Real: a nypd police car in new york city
# Pred: a busy city street with a street with a street light on a street
#
# BLEU: 0.35
# Real: black and white picture of an nypd car
# Pred: a busy city street with a street with a street light on a street
#
# BLEU: 0.70
# Real: the fresh orange has been cut and is ready to be eaten
# Pred: a close up of an orange on a wooden table
#
# BLEU: 0.44
# Real: a man on a skateboard jumping up in the air
# Pred: a skateboarder in mid air
#
# BLEU: 0.35
# Real: a nypd police car in new york city
# Pred: a busy city street with a street with a street light on a street
#
# BLEU: 0.50
# Real: a multimedia art work with scissors and paint
# Pred: a person is sitting on a table
#
# BLEU: 0.61
# Real: a number of boats are in the water near the beach
# Pred: a boat is in the water
#
# BLEU: 0.77
# Real: a woman in a swinging pose on a tennis court
# Pred: a man playing tennis on a tennis court
#
# BLEU: 0.25
# Real: a speed limit sign mounted beneath a green street sign
# Pred: a street sign on a pole on a pole on a pole on a pole on a pole on a pole on a pole
#
# BLEU: 0.78
# Real: a baseball player in action up at bat in a game
# Pred: a baseball player swinging a bat at home plate
#
# BLEU: 0.33
# Real: some apple slices and other food on a plate
# Pred: a plate of fruit and a drink on a plate with toothpicks sits on a plate with toothpicks sits on a plate with toothpicks
#
# BLEU: 0.88
# Real: a person is diving into a small wave and into the ocean
# Pred: a man riding a surfboard in the ocean
#
# BLEU: 0.87
# Real: a person standing by surfboards on a beach
# Pred: a man is standing on a beach
#
# BLEU: 0.75
# Real: a large jetliner parked on an airport tarmac
# Pred: a large white airplane parked on the tarmac
#
# BLEU: 0.78
# Real: some baseball players are playing baseball a batter and a catcher
# Pred: a baseball player swinging a bat at home plate
#
# BLEU: 0.50
# Real: scissors are lying beside a picture of a man in a gas mask
# Pred: a person is sitting on a table
#
# BLEU: 0.87
# Real: a harbor with boats anchored in lines and a large ship at dock
# Pred: a harbor with a lot of boats
#
# BLEU: 0.78
# Real: a baseball player holding a bat towards a ball
# Pred: a baseball player swinging a bat at home plate
#
# BLEU: 0.33
# Real: assortment of fruits with pastry and beverage displayed on table
# Pred: a plate of fruit and a drink on a plate with toothpicks sits on a plate with toothpicks sits on a plate with toothpicks
#
# BLEU: 0.34
# Real: a town plaza at night time with many clocks on poles
# Pred: a clock on a city street
#
# BLEU: 0.62
# Real: a hydrant in front of an assortment of green foliage with white blooms
# Pred: a fire hydrant sitting on a dirt road
#
# BLEU: 0.82
# Real: a large tractor truck with a painting on the back of the cab
# Pred: a truck with a skateboard on the back of a truck
#
# BLEU: 0.33
# Real: assortment of fruits with pastry and beverage displayed on table
# Pred: a plate of fruit and a drink on a plate with toothpicks sits on a plate with toothpicks sits on a plate with toothpicks
#
# BLEU: 0.33
# Real: a plate of fruits and ice cream and a donut
# Pred: a plate of fruit and a drink on a plate with toothpicks sits on a plate with toothpicks sits on a plate with toothpicks
#
# BLEU: 0.78
# Real: a baseball player holding a bat towards a ball
# Pred: a baseball player swinging a bat at home plate
#
# BLEU: 0.82
# Real: a semi truck with a wrestler painted on it
# Pred: a truck with a skateboard on the back of a truck
#
# BLEU: 0.88
# Real: a person is diving into a small wave and into the ocean
# Pred: a man riding a surfboard in the ocean
#
# BLEU: 0.34
# Real: a group of people who are walking near a bunch of clocks
# Pred: a clock on a city street
#
# BLEU: 0.35
# Real: an nypd police car sitting on broadway near a stoplight
# Pred: a busy city street with a street with a street light on a street
#
# BLEU: 0.62
# Real: a small fire hydrant sitting next to a lush green bush
# Pred: a fire hydrant sitting on a dirt road
#
# BLEU: 0.87
# Real: several boats docked in the pretty blue water
# Pred: a harbor with a lot of boats
#
# BLEU: 0.34
# Real: a group of people who are walking near a bunch of clocks
# Pred: a clock on a city street
#
# BLEU: 0.25
# Real: wires traffic and street signs at the corner of 51st and 72nd
# Pred: a street sign on a pole on a pole on a pole on a pole on a pole on a pole on a pole
#
# BLEU: 0.87
# Real: a ship is parked near a lot of smaller boats
# Pred: a harbor with a lot of boats
#
# BLEU: 0.40
# Real: a woman is seen in a rear view mirror with a camera while behind her a white headed dog pokes his head out the window
# Pred: a dog is taking a picture of a dog is taking a picture of a dog is taking a picture of a dog is
#
# BLEU: 0.75
# Real: a plane on the tarmac with other planes in the background
# Pred: a large white airplane parked on the tarmac
#
# BLEU: 0.88
# Real: there are two skiers that are going down the hill
# Pred: a man riding a surfboard in the snow
#
# BLEU: 0.45
# Real: a man is standing near the street with a surfboard
# Pred: a man holding a surfboard
#
# BLEU: 0.61
# Real: several boats in front of a beach with several people on it
# Pred: a boat is in the water
#
# BLEU: 0.70
# Real: a hand holding up an orange slice next to a wall
# Pred: a close up of an orange on a wooden table
#
# BLEU: 0.88
# Real: a person is diving into a small wave and into the ocean
# Pred: a man riding a surfboard in the ocean
#
# BLEU: 0.33
# Real: some apples and strawberries are on a plate
# Pred: a plate of fruit and a drink on a plate with toothpicks sits on a plate with toothpicks sits on a plate with toothpicks
#
# BLEU: 0.33
# Real: some apple slices and other food on a plate
# Pred: a plate of fruit and a drink on a plate with toothpicks sits on a plate with toothpicks sits on a plate with toothpicks
#
# BLEU: 0.89
# Real: an image of a living room setting with furniture
# Pred: a living room with a couch and a table
#
# BLEU: 0.60
# Real: a baby holding a toothbrush in a living room
# Pred: a young child brushing her teeth
#
# BLEU: 0.40
# Real: a lady taking a picture in a car mirror of a dog sticking it s head out the window
# Pred: a dog is taking a picture of a dog is taking a picture of a dog is taking a picture of a dog is
#
# BLEU: 0.80
# Real: a couple of people on skis in the snow
# Pred: a group of people are on a snow covered slope
#
# BLEU: 0.34
# Real: several clocks in night scene with lights and crowd walking
# Pred: a clock on a city street
#
# BLEU: 0.75
# Real: a plane on the tarmac with other planes in the background
# Pred: a large white airplane parked on the tarmac
#
# BLEU: 0.56
# Real: a man eating an long hot dog with toppings
# Pred: a person holding a hot dog in his mouth
#
# BLEU: 0.40
# Real: a woman takes a picture of the reflection of a dog in a car mirror
# Pred: a dog is taking a picture of a dog is taking a picture of a dog is taking a picture of a dog is
#
# BLEU: 0.50
# Real: a couple of woman with suitcases on the road
# Pred: a woman is walking down the street
#
# BLEU: 0.61
# Real: a number of boats are in the water near the beach
# Pred: a boat is in the water
#
# BLEU: 0.56
# Real: a young man eats a loaded hot dog
# Pred: a person holding a hot dog in his mouth
#
# BLEU: 0.89
# Real: a beige sectional sofa next to a fireplace and a mirror
# Pred: a living room with a couch and a table
#
# BLEU: 0.80
# Real: a man and a young child skiing across a snow covered slope
# Pred: a group of people are on a snow covered slope
#
# BLEU: 0.88
# Real: two snow skiers one in a red jacket and trees
# Pred: a man riding a surfboard in the snow
#
# BLEU: 0.70
# Real: a close up of a person holding a slice of orange
# Pred: a close up of an orange on a wooden table
#
# BLEU: 0.82
# Real: a truck with a portrait of a man in a black suit and black hat
# Pred: a truck with a skateboard on the back of a truck
#
# BLEU: 0.87
# Real: a man stands on a beach with a bunch of surf boards
# Pred: a man is standing on a beach
#
# BLEU: 0.50
# Real: a vulture stands alone next a muddy and flooded field
# Pred: a bird with a black and black and white bird with a black beak is sitting on a body of a body of a
#
# BLEU: 0.33
# Real: some apple slices and other food on a plate
# Pred: a plate of fruit and a drink on a plate with toothpicks sits on a plate with toothpicks sits on a plate with toothpicks
#
# BLEU: 0.88
# Real: a man riding skis down a snow covered slope
# Pred: a man riding a surfboard in the snow
#
# BLEU: 0.44
# Real: a person is jumping a skateboard over a barrel
# Pred: a skateboarder in mid air
#
# BLEU: 0.80
# Real: a couple of people on skis in the snow
# Pred: a group of people are on a snow covered slope
#
# BLEU: 0.77
# Real: a woman swinging a tennis racket on a tennis court
# Pred: a man playing tennis on a tennis court
#
# BLEU: 0.56
# Real: a man eating a very long hot dog
# Pred: a person holding a hot dog in his mouth
#
# BLEU: 0.45
# Real: a man holds a surfboard on a lawn near houses
# Pred: a man holding a surfboard
#
# BLEU: 0.61
# Real: yellow and white boats floating in the water in front of a beach
# Pred: a boat is in the water
#
# BLEU: 0.50
# Real: a grey and white bird in a swampy marsh
# Pred: a bird with a black and black and white bird with a black beak is sitting on a body of a body of a
#
# BLEU: 0.50
# Real: a bird with a large beak is standing the the water
# Pred: a bird with a black and black and white bird with a black beak is sitting on a body of a body of a
#
# BLEU: 0.34
# Real: several clocks in night scene with lights and crowd walking
# Pred: a clock on a city street
#
# BLEU: 0.50
# Real: two women with lots of luggage walk through a parking lot
# Pred: a woman is walking down the street
#
# BLEU: 0.33
# Real: a white plate topped with fruit and pastry
# Pred: a plate of fruit and a drink on a plate with toothpicks sits on a plate with toothpicks sits on a plate with toothpicks
#
# BLEU: 0.44
# Real: boy on a skateboard jumping over a barrel
# Pred: a skateboarder in mid air
#
# BLEU: 0.35
# Real: black and white picture of an nypd car
# Pred: a busy city street with a street with a street light on a street
#
# BLEU: 0.77
# Real: a woman swinging a tennis racket on a tennis court
# Pred: a man playing tennis on a tennis court
#
# BLEU: 0.87
# Real: a ship is parked near a lot of smaller boats
# Pred: a harbor with a lot of boats
#
# BLEU: 0.88
# Real: two people going through the snow on skis
# Pred: a man riding a surfboard in the snow
#
# BLEU: 0.82
# Real: a truck with a portrait of a man in a black suit and black hat
# Pred: a truck with a skateboard on the back of a truck
#
# BLEU: 0.87
# Real: colorful scenery jam packed with surfboards and a tanned surfer
# Pred: a man is standing on a beach
#
# BLEU: 0.75
# Real: armavia air plane on tar mack with other planes in the distance
# Pred: a large white airplane parked on the tarmac
#
# BLEU: 0.40
# Real: a lady taking a picture in a car mirror of a dog sticking it s head out the window
# Pred: a dog is taking a picture of a dog is taking a picture of a dog is taking a picture of a dog is
#
# BLEU: 0.60
# Real: a young child brushing his teeth by himself
# Pred: a young child brushing her teeth
#
# BLEU: 0.33
# Real: a plate of fruits and ice cream and a donut
# Pred: a plate of fruit and a drink on a plate with toothpicks sits on a plate with toothpicks sits on a plate with toothpicks
#
# BLEU: 0.60
# Real: a baby puts a tooth brush in its mouth
# Pred: a young child brushing her teeth
#
# BLEU: 0.61
# Real: a yellow and white boat is in an ocean near the beach
# Pred: a boat is in the water
#
# BLEU: 0.45
# Real: a man standing in a yard holding a surfboard
# Pred: a man holding a surfboard
#
# BLEU: 0.44
# Real: boy on a skateboard jumping over a barrel
# Pred: a skateboarder in mid air
#
# BLEU: 0.25
# Real: street name and speed limit signs on a common pole
# Pred: a street sign on a pole on a pole on a pole on a pole on a pole on a pole on a pole
#
# BLEU: 0.33
# Real: some apples and strawberries are on a plate
# Pred: a plate of fruit and a drink on a plate with toothpicks sits on a plate with toothpicks sits on a plate with toothpicks
#
# BLEU: 0.88
# Real: a man riding skis down a snow covered slope
# Pred: a man riding a surfboard in the snow
#
# BLEU: 0.82
# Real: a semi truck with a wrestler painted on it
# Pred: a truck with a skateboard on the back of a truck
#
# BLEU: 0.88
# Real: a man rides a wave on a surfboard
# Pred: a man riding a surfboard in the ocean
#
# BLEU: 0.88
# Real: a person is diving into a small wave and into the ocean
# Pred: a man riding a surfboard in the ocean
#
# BLEU: 0.62
# Real: a small fire hydrant sitting next to a lush green bush
# Pred: a fire hydrant sitting on a dirt road
#
# BLEU: 0.75
# Real: armavia air plane on tar mack with other planes in the distance
# Pred: a large white airplane parked on the tarmac
#
# BLEU: 0.77
# Real: a woman swinging a tennis racket on a tennis court
# Pred: a man playing tennis on a tennis court
#
# BLEU: 0.77
# Real: a female tennis player having just hit the ball
# Pred: a man playing tennis on a tennis court
#
# BLEU: 0.60
# Real: a baby is using a toothbrush to brush his teeth
# Pred: a young child brushing her teeth
#
# BLEU: 0.40
# Real: a woman taking a picture of her dog in the car mirror
# Pred: a dog is taking a picture of a dog is taking a picture of a dog is taking a picture of a dog is
#
# BLEU: 0.25
# Real: a sign on a post that says 72 st
# Pred: a street sign on a pole on a pole on a pole on a pole on a pole on a pole on a pole
#
# BLEU: 0.89
# Real: a living room with a couch fireplace and wood floors
# Pred: a living room with a couch and a table
#
# BLEU: 0.80
# Real: a man and a small child skiing together
# Pred: a group of people are on a snow covered slope
#
# BLEU: 0.75
# Real: armavia air plane on tar mack with other planes in the distance
# Pred: a large white airplane parked on the tarmac
#
# BLEU: 0.34
# Real: a group of people who are walking near a bunch of clocks
# Pred: a clock on a city street
#
# BLEU: 0.77
# Real: a woman is swinging a tennis racket on a court
# Pred: a man playing tennis on a tennis court
#
# BLEU: 0.88
# Real: there are two skiers that are going down the hill
# Pred: a man riding a surfboard in the snow
#
# BLEU: 0.82
# Real: a truck that is driving in a parking lot
# Pred: a truck with a skateboard on the back of a truck
#
# BLEU: 0.40
# Real: a woman is seen in a rear view mirror with a camera while behind her a white headed dog pokes his head out the window
# Pred: a dog is taking a picture of a dog is taking a picture of a dog is taking a picture of a dog is
#
# BLEU: 0.82
# Real: a truck with a portrait of a man in a black suit and black hat
# Pred: a truck with a skateboard on the back of a truck
#
# BLEU: 0.88
# Real: a man rides a wave on a surfboard
# Pred: a man riding a surfboard in the ocean
#
# BLEU: 0.50
# Real: a close up of a bird in a body of water with grass
# Pred: a bird with a black and black and white bird with a black beak is sitting on a body of a body of a
#
# BLEU: 0.50
# Real: a vulture stands alone next a muddy and flooded field
# Pred: a bird with a black and black and white bird with a black beak is sitting on a body of a body of a
#
# BLEU: 0.34
# Real: a group of people who are walking near a bunch of clocks
# Pred: a clock on a city street
#
# BLEU: 0.88
# Real: there are two skiers that are going down the hill
# Pred: a man riding a surfboard in the snow
#
# BLEU: 0.35
# Real: a car and traffic light on a city street
# Pred: a busy city street with a street with a street light on a street
#
# BLEU: 0.87
# Real: a large ship is on the water near docked small boats
# Pred: a harbor with a lot of boats
#
# BLEU: 0.70
# Real: the fresh orange has been cut and is ready to be eaten
# Pred: a close up of an orange on a wooden table
#
# BLEU: 0.33
# Real: a plate of fruits and ice cream and a donut
# Pred: a plate of fruit and a drink on a plate with toothpicks sits on a plate with toothpicks sits on a plate with toothpicks
# +-----+------------------+--------+--------------+-------------+
# |     | Image            |   BLEU |   Total_Time |   Comm_Time |
# |-----+------------------+--------+--------------+-------------|
# |   0 | 000000470770.jpg |   0.5  |         0.77 |        0.76 |
# |   1 | 000000023066.jpg |   0.82 |         0.76 |        0.75 |
# |   2 | 000000010920.jpg |   0.35 |         0.83 |        0.82 |
# |   3 | 000000545796.jpg |   0.6  |         0.63 |        0.63 |
# |   4 | 000000389811.jpg |   0.25 |         1.31 |        1.31 |
# |   5 | 000000428460.jpg |   0.75 |         0.59 |        0.59 |
# |   6 | 000000354333.jpg |   0.7  |         0.67 |        0.66 |
# |   7 | 000000354333.jpg |   0.7  |         0.63 |        0.62 |
# |   8 | 000000010920.jpg |   0.35 |         0.67 |        0.66 |
# |   9 | 000000010920.jpg |   0.35 |         0.73 |        0.72 |
# |  10 | 000000354333.jpg |   0.7  |         0.63 |        0.62 |
# |  11 | 000000120370.jpg |   0.44 |         0.5  |        0.49 |
# |  12 | 000000010920.jpg |   0.35 |         0.69 |        0.68 |
# |  13 | 000000547147.jpg |   0.5  |         0.58 |        0.57 |
# |  14 | 000000049165.jpg |   0.61 |         0.51 |        0.5  |
# |  15 | 000000504620.jpg |   0.77 |         0.58 |        0.56 |
# |  16 | 000000389811.jpg |   0.25 |         0.85 |        0.85 |
# |  17 | 000000542024.jpg |   0.78 |         0.6  |        0.59 |
# |  18 | 000000514440.jpg |   0.33 |         0.88 |        0.87 |
# |  19 | 000000529455.jpg |   0.88 |         0.6  |        0.59 |
# |  20 | 000000351539.jpg |   0.87 |         0.63 |        0.62 |
# |  21 | 000000428460.jpg |   0.75 |         0.6  |        0.6  |
# |  22 | 000000542024.jpg |   0.78 |         0.68 |        0.67 |
# |  23 | 000000547147.jpg |   0.5  |         0.72 |        0.71 |
# |  24 | 000000324877.jpg |   0.87 |         0.64 |        0.63 |
# |  25 | 000000542024.jpg |   0.78 |         0.81 |        0.8  |
# |  26 | 000000514440.jpg |   0.33 |         0.94 |        0.93 |
# |  27 | 000000346924.jpg |   0.34 |         0.96 |        0.95 |
# |  28 | 000000501667.jpg |   0.62 |         0.93 |        0.92 |
# |  29 | 000000023066.jpg |   0.82 |         0.9  |        0.88 |
# |  30 | 000000514440.jpg |   0.33 |         1.29 |        1.28 |
# |  31 | 000000514440.jpg |   0.33 |         1.37 |        1.36 |
# |  32 | 000000542024.jpg |   0.78 |         0.86 |        0.85 |
# |  33 | 000000023066.jpg |   0.82 |         0.92 |        0.91 |
# |  34 | 000000529455.jpg |   0.88 |         0.89 |        0.88 |
# |  35 | 000000346924.jpg |   0.34 |         0.74 |        0.73 |
# |  36 | 000000010920.jpg |   0.35 |         0.89 |        0.88 |
# |  37 | 000000501667.jpg |   0.62 |         0.86 |        0.85 |
# |  38 | 000000324877.jpg |   0.87 |         0.78 |        0.77 |
# |  39 | 000000346924.jpg |   0.34 |         0.74 |        0.73 |
# |  40 | 000000389811.jpg |   0.25 |         1.25 |        1.24 |
# |  41 | 000000324877.jpg |   0.87 |         0.83 |        0.82 |
# |  42 | 000000040211.jpg |   0.4  |         1.17 |        1.17 |
# |  43 | 000000428460.jpg |   0.75 |         0.78 |        0.77 |
# |  44 | 000000561203.jpg |   0.88 |         0.77 |        0.76 |
# |  45 | 000000250035.jpg |   0.45 |         0.68 |        0.67 |
# |  46 | 000000049165.jpg |   0.61 |         0.75 |        0.74 |
# |  47 | 000000354333.jpg |   0.7  |         0.83 |        0.82 |
# |  48 | 000000529455.jpg |   0.88 |         0.81 |        0.8  |
# |  49 | 000000514440.jpg |   0.33 |         1.02 |        1.01 |
# |  50 | 000000514440.jpg |   0.33 |         1.22 |        1.21 |
# |  51 | 000000346990.jpg |   0.89 |         0.99 |        0.98 |
# |  52 | 000000545796.jpg |   0.6  |         0.83 |        0.82 |
# |  53 | 000000040211.jpg |   0.4  |         1.28 |        1.27 |
# |  54 | 000000187007.jpg |   0.8  |         0.72 |        0.72 |
# |  55 | 000000346924.jpg |   0.34 |         0.57 |        0.56 |
# |  56 | 000000428460.jpg |   0.75 |         0.65 |        0.64 |
# |  57 | 000000130972.jpg |   0.56 |         0.78 |        0.77 |
# |  58 | 000000040211.jpg |   0.4  |         0.91 |        0.9  |
# |  59 | 000000470770.jpg |   0.5  |         0.63 |        0.63 |
# |  60 | 000000049165.jpg |   0.61 |         0.61 |        0.6  |
# |  61 | 000000130972.jpg |   0.56 |         0.64 |        0.63 |
# |  62 | 000000346990.jpg |   0.89 |         0.69 |        0.69 |
# |  63 | 000000187007.jpg |   0.8  |         0.63 |        0.63 |
# |  64 | 000000561203.jpg |   0.88 |         0.59 |        0.58 |
# |  65 | 000000354333.jpg |   0.7  |         0.64 |        0.63 |
# |  66 | 000000023066.jpg |   0.82 |         0.66 |        0.65 |
# |  67 | 000000351539.jpg |   0.87 |         0.73 |        0.72 |
# |  68 | 000000209063.jpg |   0.5  |         1.23 |        1.22 |
# |  69 | 000000514440.jpg |   0.33 |         1.51 |        1.5  |
# |  70 | 000000561203.jpg |   0.88 |         0.88 |        0.87 |
# |  71 | 000000120370.jpg |   0.44 |         0.84 |        0.83 |
# |  72 | 000000187007.jpg |   0.8  |         0.9  |        0.89 |
# |  73 | 000000504620.jpg |   0.77 |         0.97 |        0.96 |
# |  74 | 000000130972.jpg |   0.56 |         0.84 |        0.83 |
# |  75 | 000000250035.jpg |   0.45 |         0.83 |        0.82 |
# |  76 | 000000049165.jpg |   0.61 |         0.81 |        0.8  |
# |  77 | 000000209063.jpg |   0.5  |         1.11 |        1.1  |
# |  78 | 000000209063.jpg |   0.5  |         0.92 |        0.91 |
# |  79 | 000000346924.jpg |   0.34 |         0.61 |        0.6  |
# |  80 | 000000470770.jpg |   0.5  |         0.6  |        0.59 |
# |  81 | 000000514440.jpg |   0.33 |         0.88 |        0.88 |
# |  82 | 000000120370.jpg |   0.44 |         0.55 |        0.55 |
# |  83 | 000000010920.jpg |   0.35 |         0.72 |        0.72 |
# |  84 | 000000504620.jpg |   0.77 |         0.63 |        0.63 |
# |  85 | 000000324877.jpg |   0.87 |         0.67 |        0.66 |
# |  86 | 000000561203.jpg |   0.88 |         0.85 |        0.83 |
# |  87 | 000000023066.jpg |   0.82 |         0.66 |        0.65 |
# |  88 | 000000351539.jpg |   0.87 |         0.61 |        0.6  |
# |  89 | 000000428460.jpg |   0.75 |         0.64 |        0.63 |
# |  90 | 000000040211.jpg |   0.4  |         0.93 |        0.93 |
# |  91 | 000000545796.jpg |   0.6  |         0.59 |        0.58 |
# |  92 | 000000514440.jpg |   0.33 |         0.91 |        0.9  |
# |  93 | 000000545796.jpg |   0.6  |         0.78 |        0.77 |
# |  94 | 000000049165.jpg |   0.61 |         0.58 |        0.58 |
# |  95 | 000000250035.jpg |   0.45 |         0.6  |        0.59 |
# |  96 | 000000120370.jpg |   0.44 |         0.66 |        0.65 |
# |  97 | 000000389811.jpg |   0.25 |         1.15 |        1.15 |
# |  98 | 000000514440.jpg |   0.33 |         1.29 |        1.28 |
# |  99 | 000000561203.jpg |   0.88 |         0.85 |        0.84 |
# | 100 | 000000023066.jpg |   0.82 |         0.91 |        0.9  |
# | 101 | 000000529455.jpg |   0.88 |         0.93 |        0.92 |
# | 102 | 000000529455.jpg |   0.88 |         0.83 |        0.82 |
# | 103 | 000000501667.jpg |   0.62 |         0.86 |        0.85 |
# | 104 | 000000428460.jpg |   0.75 |         0.84 |        0.83 |
# | 105 | 000000504620.jpg |   0.77 |         0.9  |        0.89 |
# | 106 | 000000504620.jpg |   0.77 |         0.93 |        0.92 |
# | 107 | 000000545796.jpg |   0.6  |         0.9  |        0.89 |
# | 108 | 000000040211.jpg |   0.4  |         1.02 |        1.01 |
# | 109 | 000000389811.jpg |   0.25 |         0.93 |        0.93 |
# | 110 | 000000346990.jpg |   0.89 |         0.66 |        0.65 |
# | 111 | 000000187007.jpg |   0.8  |         0.65 |        0.64 |
# | 112 | 000000428460.jpg |   0.75 |         0.57 |        0.56 |
# | 113 | 000000346924.jpg |   0.34 |         0.55 |        0.54 |
# | 114 | 000000504620.jpg |   0.77 |         0.6  |        0.59 |
# | 115 | 000000561203.jpg |   0.88 |         0.61 |        0.6  |
# | 116 | 000000023066.jpg |   0.82 |         0.81 |        0.8  |
# | 117 | 000000040211.jpg |   0.4  |         0.9  |        0.89 |
# | 118 | 000000023066.jpg |   0.82 |         0.73 |        0.72 |
# | 119 | 000000529455.jpg |   0.88 |         0.59 |        0.58 |
# | 120 | 000000209063.jpg |   0.5  |         0.91 |        0.9  |
# | 121 | 000000209063.jpg |   0.5  |         0.87 |        0.86 |
# | 122 | 000000346924.jpg |   0.34 |         0.58 |        0.57 |
# | 123 | 000000561203.jpg |   0.88 |         0.62 |        0.6  |
# | 124 | 000000010920.jpg |   0.35 |         0.71 |        0.7  |
# | 125 | 000000324877.jpg |   0.87 |         0.6  |        0.59 |
# | 126 | 000000354333.jpg |   0.7  |         0.61 |        0.6  |
# | 127 | 000000514440.jpg |   0.33 |         1.04 |        1.04 |
# +-----+------------------+--------+--------------+-------------+
# Average BLEU                    : 0.62
# Average inference time          : 0.72 s
# Average head model time         : 0.01 s
# Average communication time      : 0.00 s
# Average tail model time         : 0.71 s
# Average communication payload   : 1,072,812
